# %%
#Execute this cell if have problem with relative import

import sys; sys.path.insert(0, '..')

# %%
from pprint import pprint

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
bat_df = pd.read_csv("../Data/Corpus_csv/batters_ten_season.csv")

# %%
bat_df.head()
# Out:
#                 Id         Name  Active  First year  Last year  \
# 0   Alan_Ashby_602   Alan Ashby   False        1973       1989
# 1   Alex_Arias_531   Alex Arias   False        1992       2002
# 2   Alex_Avila_677   Alex Avila   False        2009       2021
# 3    Henry_Aaron_2  Henry Aaron   False        1954       1976
# 4  Luis_Aguayo_137  Luis Aguayo   False        1980       1989
#
#                                                  Url Country Bat hand  \
# 0  https://www.baseball-reference.com//players/a/...      us     Both
# 1  https://www.baseball-reference.com//players/a/...      us    Right
# 2  https://www.baseball-reference.com//players/a/...      us     Left
# 3  https://www.baseball-reference.com//players/a/...      us    Right
# 4  https://www.baseball-reference.com//players/a/...      pr    Right
#
#   Throw hand               Full Name  HoF HoF type HoF year HoF comittee  \
# 0      Right         Alan Dean Ashby    0        -        -            -
# 1      Right         Alejandro Arias    0        -        -            -
# 2      Right  Alexander Thomas Avila    0        -        -            -
# 3      Right       Henry Louis Aaron    1   Player     1982        BBWAA
# 4      Right             Luis Aguayo    0        -        -            -
#
#    Player type retirement_age  total_seasons  \
# 0            2             37             17
# 1            2             34             11
# 2            2             34             13
# 3            2             42             23
# 4            2             30             10
#
#                           career_teams career_leagues first_position  \
# 0                ['CLE', 'TOR', 'HOU']   ['AL', 'NL']              C
# 1  ['CHC', 'FLA', 'PHI', 'SDP', 'NYY']   ['NL', 'AL']             SS
# 2  ['DET', 'CHW', 'ARI', 'MIN', 'WSN']   ['AL', 'NL']              C
# 3                ['MLN', 'ATL', 'MIL']   ['NL', 'AL']             OF
# 4                       ['PHI', 'CLE']   ['NL', 'AL']             SS
#
#   second_position  play_in_mayors  play_in_negro_league  two_way_player  \
# 0               -               1                     0               0
# 1              3B               1                     0               0
# 2              1B               1                     0               0
# 3              RF               1                     0               0
# 4              3B               1                     0               0
#
#    debut_decade  retirament_decade ten_season_age  2B_bt  3B_bt   AB_bt  \
# 0          1970               1980           30.0  108.0   11.0  2479.0
# 1          1990               2000           33.0   84.0    6.0  1766.0
# 2          2000               2020           31.0  136.0    8.0  2758.0
# 3          1950               1970           29.0  321.0   77.0  5940.0
# 4          1980               1980           30.0   43.0   10.0  1104.0
#
#    BB_bt  CS_bt    G_bt  HR_bt    H_bt  IBB_bt   PA_bt  RBI_bt    R_bt  SB_bt  \
# 0  261.0    9.0   812.0   42.0   588.0    44.0  2813.0   290.0   230.0    6.0
# 1  180.0    5.0   769.0   18.0   470.0    14.0  2002.0   196.0   203.0   10.0
# 2  462.0    8.0   932.0   94.0   654.0    16.0  3264.0   362.0   319.0    7.0
# 3  541.0   37.0  1511.0  342.0  1898.0   124.0  6582.0  1121.0  1077.0  103.0
# 4   94.0    5.0   568.0   37.0   260.0    12.0  1244.0   109.0   142.0    7.0
#
#    HBP_bt  SF_bt  SH_bt  SO_bt  BA_bt  OBP_bt  OPS_bt  SLG_bt   TB_bt    A_fd  \
# 0     7.0   18.0   46.0  383.0  0.237   0.310   0.753   0.443  1005.0   434.0
# 1    23.0   16.0   17.0  209.0  0.266   0.339   0.772   0.433   728.0  1016.0
# 2    14.0   20.0   10.0  941.0  0.237   0.347   0.921   0.574  1326.0   376.0
# 3    20.0   62.0   19.0  609.0  0.320   0.375   1.206   0.831  4139.0   318.0
# 4    20.0   12.0   14.0  220.0  0.236   0.304   0.852   0.548   524.0   867.0
#
#     CG_fd  CS_fd  DP_fd   E_fd   GS_fd    G_fd   Inn_fd  PB_fd   PO_fd  SB_fd  \
# 0   645.0  292.0   57.0   68.0   738.0   800.0   6530.2   60.0  4121.0  595.0
# 1   320.0    0.0  183.0   46.0   398.0   580.0   3761.0    0.0   645.0    0.0
# 2   693.0  193.0   77.0   34.0   804.0   891.0   7042.1   53.0  6093.0  467.0
# 3  2831.0    0.0   63.0  147.0  2957.0  3008.0  26416.1    0.0  6094.0    0.0
# 4   183.0    0.0  148.0   54.0   268.0   505.0   2727.0    0.0   483.0    0.0
#
#    WP_fd   Ch_fd  Fld%_fd
# 0  213.0  4623.0    0.985
# 1    0.0  1707.0    0.973
# 2  274.0  6503.0    0.995
# 3    0.0  6559.0    0.978
# 4    0.0  1404.0    0.962

# %%
bat_df["ten_season_age"].value_counts()
# Out:
# 32.0           434
# 31.0           407
# 33.0           365
# 30.0           343
# 29.0           206
# 34.0           206
# 35.0           113
# 28.0            93
# 36.0            62
# 37.0            33
# 27.0            28
# 38.0            16
# 26.0             9
# 39.0             8
# 40.0             5
# 46.0             2
# desconocido      2
# 43.0             2
# 44.0             1
# 45.0             1
# 48.0             1
# 42.0             1
# 41.0             1
# Name: ten_season_age, dtype: int64

# %%
bat_df.shape
# Out:
# (2339, 63)

# %%
from Preprocessing.data_frame_procces import filter_dataset, select_features

# %%
bat_df['retirement_age'] = (
        bat_df['retirement_age'].replace('desconocido', bat_df['retirement_age'].mode()[0])
    )
bat_df['retirement_age'] = bat_df['retirement_age'].astype('int64')

bat_df['ten_season_age'] = (
        bat_df['ten_season_age'].replace('desconocido', bat_df['ten_season_age'].mode()[0])
    )
bat_df['ten_season_age'] = bat_df['ten_season_age'].astype('float64').round(0).astype('int64')

# %%
eq_conditions = {
    "HoF type":['-','Player']
}
filter_df = filter_dataset(bat_df, eq_conditions,None, None, None)

# %%
filter_df.shape
# Out:
# (2323, 63)

# %%
filter_df.describe()
# Out:
#         First year    Last year          HoF  Player type  retirement_age  \
# count  2323.000000  2323.000000  2323.000000       2323.0     2323.000000
# mean   1958.839862  1972.056823     0.077486          2.0       35.421007
# std      37.834483    37.174429     0.267419          0.0        3.302718
# min    1871.000000  1882.000000     0.000000          2.0       27.000000
# 25%    1929.000000  1945.000000     0.000000          2.0       33.000000
# 50%    1967.000000  1980.000000     0.000000          2.0       35.000000
# 75%    1991.000000  2004.000000     0.000000          2.0       37.000000
# max    2013.000000  2022.000000     1.000000          2.0       58.000000
#
#        total_seasons  play_in_mayors  play_in_negro_league  two_way_player  \
# max    1632.000000     0.382000     0.484000     1.524000     1.063000
#
#              TB_bt         A_fd        CG_fd        CS_fd        DP_fd  \
# count  2323.000000  2323.000000  2323.000000  2323.000000  2323.000000
# mean   1645.171330  1063.064572   938.322428    41.339647   245.365476
# std     775.747946  1176.106946   652.955296   114.049166   281.307562
# min      67.000000     2.000000     0.000000     0.000000     0.000000
# 25%    1028.500000   180.000000   453.500000     0.000000    38.000000
# 50%    1646.000000   477.000000   895.000000     0.000000    98.000000
# 75%    2178.000000  1783.500000  1281.000000     0.000000   381.500000
# max    4429.000000  5155.000000  3478.000000   965.000000  1376.000000
#
#               E_fd        GS_fd         G_fd        Inn_fd        PB_fd  \
# count  2323.000000  2323.000000  2323.000000   2323.000000  2323.000000
# mean    122.275936  1083.267327  1264.527766   9502.999656    12.347826
# std     103.864937   688.458134   631.267366   4920.690841    39.999144
# min       2.000000     0.000000    71.000000    255.100000     0.000000
# 25%      56.000000   593.500000   824.000000   6166.000000     0.000000
# 50%      93.000000  1045.000000  1158.000000   9065.000000     0.000000
# 75%     151.000000  1432.500000  1595.000000  11518.100000     0.000000
# max     853.000000  3660.000000  3786.000000  27231.100000   579.000000
#
#               PO_fd        SB_fd        WP_fd         Ch_fd      Fld%_fd
# count   2323.000000  2323.000000  2323.000000   2323.000000  2323.000000
# mean    3391.827378    69.048214    23.942316   4577.167886     0.969859
# std     2415.215762   171.278456    65.707310   2410.880979     0.024534
# min       57.000000     0.000000     0.000000    130.000000     0.815000
# 25%     1653.000000     0.000000     0.000000   3011.000000     0.963000
# 50%     2801.000000     0.000000     0.000000   4289.000000     0.976000
# 75%     4462.500000     0.000000     0.000000   5794.000000     0.986000
# max    15990.000000  1259.000000   455.000000  17310.000000     0.998000

# %%
data_set_bat_header = ["2B_bt","3B_bt","AB_bt","BB_bt","CS_bt","G_bt","HR_bt","H_bt","IBB_bt","PA_bt","RBI_bt","R_bt","SB_bt","HBP_bt","SF_bt","SH_bt","SO_bt","BA_bt","OBP_bt","OPS_bt","SLG_bt","TB_bt","A_fd","CG_fd","CS_fd","DP_fd","E_fd","GS_fd","G_fd","Inn_fd","PB_fd","PO_fd","SB_fd","WP_fd","Ch_fd","Fld%_fd"]
for h in data_set_bat_header:
    nan = filter_df[h].isna().any()
    if nan:
        print(f"{h}:{nan} --->{filter_df[h].isna().sum()}")

# %%
print(filter_df['HoF'].value_counts())
# Out:
# 0    2143
# 1     180
# Name: HoF, dtype: int64

# %%
inactives_cond = {"Active":[False]}
inactive_bat_df = filter_dataset(filter_df, inactives_cond, None, None, None)

# %%
inactive_bat_df.shape
# Out:
# (2233, 63)

# %%
negro_league_condition = {
    'play_in_negro_league':[1]
}
negro_lg_bat_df = filter_dataset(filter_df, negro_league_condition, None, None, None)

# %%
negro_lg_bat_df.shape
# Out:
# (136, 63)

# %%
negro_lg_bat_df['HoF'].value_counts()
# Out:
# 0    117
# 1     19
# Name: HoF, dtype: int64

# %%
mayor_league_condition = {
    'play_in_mayors':[1]
}
mayors_lg_bat_df = filter_dataset(filter_df, mayor_league_condition, None, None, None)

# %%
mayors_lg_bat_df.shape
# Out:
# (2231, 63)

# %%
drop_recent_election_cond = {
    'retirament_decade':2009
}
inactive_mayors_lg_bat_df = filter_dataset(inactive_bat_df, mayor_league_condition, None, drop_recent_election_cond, None)

# %%
inactive_mayors_lg_bat_df.shape
# Out:
# (1807, 63)

# %%
inactive_mayors_lg_bat_df.describe()
# Out:
#         First year    Last year          HoF  Player type  retirement_age  \
# count  1807.000000  1807.000000  1807.000000       1807.0     1807.000000
# mean   1949.786386  1963.158827     0.089651          2.0       35.395130
# std      34.680040    34.268850     0.285761          0.0        3.240274
# min    1871.000000  1882.000000     0.000000          2.0       27.000000
# 25%    1923.000000  1937.000000     0.000000          2.0       33.000000
# 50%    1959.000000  1972.000000     0.000000          2.0       35.000000
# 75%    1979.000000  1992.000000     0.000000          2.0       37.000000
# max    2000.000000  2009.000000     1.000000          2.0       58.000000
#
#        total_seasons  play_in_mayors  play_in_negro_league  two_way_player  \
# count    1807.000000          1807.0           1807.000000     1807.000000
# mean       13.538462             1.0              0.024350        0.001660
# std         3.132288             0.0              0.154175        0.040723
# min        10.000000             1.0              0.000000        0.000000
# 25%        11.000000             1.0              0.000000        0.000000
# 50%        13.000000             1.0              0.000000        0.000000
# 75%        15.000000             1.0              0.000000        0.000000
# max        27.000000             1.0              1.000000        1.000000
#
#        debut_decade  retirament_decade  ten_season_age        2B_bt  \
# count   1807.000000        1807.000000     1807.000000  1807.000000
# mean    1945.428888        1958.505811       31.634200   155.941893
# std       34.733941          34.246886        2.232996    72.685387
# min     1870.000000        1880.000000       26.000000     6.000000
# 25%     1920.000000        1930.000000       30.000000   101.000000
# 50%     1950.000000        1970.000000       32.000000   152.000000
# 75%     1970.000000        1990.000000       33.000000   206.000000
# max     2000.000000        2000.000000       43.000000   416.000000
#
#              3B_bt        AB_bt        BB_bt        CS_bt         G_bt  \
# count  1807.000000  1807.000000  1807.000000  1807.000000  1807.000000
# mean     36.251245  3376.382402   323.418373    29.488655   986.492529
# std      28.203068  1239.218115   180.146793    27.236338   276.279265
# min       0.000000   252.000000    10.000000     0.000000   140.000000
# 25%      15.000000  2460.500000   188.000000     8.000000   815.500000
# 50%      29.000000  3523.000000   293.000000    23.000000  1024.000000
# 75%      50.000000  4336.500000   428.000000    44.000000  1197.000000
# max     160.000000  6267.000000  1327.000000   187.000000  1544.000000
#
#              HR_bt         H_bt       IBB_bt        PA_bt       RBI_bt  \
# count  1807.000000  1807.000000  1807.000000  1807.000000  1807.000000
# mean     70.512452   927.996680    23.048146  3785.800775   426.255672
# std      67.097784   385.886678    25.150563  1403.130686   216.875484
# min       0.000000    48.000000     0.000000   276.000000    21.000000
# 25%      20.000000   627.000000     2.000000  2725.500000   263.000000
# 50%      47.000000   946.000000    17.000000  3924.000000   396.000000
# 75%     101.000000  1210.000000    34.000000  4886.000000   558.500000
# max     370.000000  2036.000000   196.000000  6955.000000  1277.000000
#
#               R_bt        SB_bt       HBP_bt        SF_bt        SH_bt  \
# count  1807.000000  1807.000000  1807.000000  1807.000000  1807.000000
# mean    478.776978    81.565578    23.403431    16.287770    44.192031
# std     233.629420    95.392452    21.540799    17.265376    45.110056
# min      20.000000     0.000000     0.000000     0.000000     0.000000
# 25%     294.000000    18.000000    10.000000     0.000000    13.000000
# 50%     469.000000    45.000000    18.000000    13.000000    30.000000
# 75%     634.000000   111.500000    30.000000    28.000000    60.000000
# max    1350.000000   794.000000   263.000000    91.000000   276.000000
#
#              SO_bt        BA_bt       OBP_bt       OPS_bt       SLG_bt  \
# count  1807.000000  1807.000000  1807.000000  1807.000000  1807.000000
# mean    400.264527     0.269949     0.335014     0.835297     0.500282
# std     231.215084     0.026542     0.033382     0.145585     0.126054
# min       0.000000     0.161000     0.195000     0.403000     0.208000
# 25%     231.000000     0.253000     0.314000     0.728000     0.403000
# 50%     366.000000     0.268000     0.333000     0.821000     0.483000
# 75%     532.000000     0.286000     0.356000     0.929000     0.580000
# max    1384.000000     0.377000     0.484000     1.524000     1.047000
#
#              TB_bt         A_fd        CG_fd        CS_fd        DP_fd  \
# count  1807.000000  1807.000000  1807.000000  1807.000000  1807.000000
# mean   1630.684007  1101.648035   958.234643    46.681240   248.017709
# std     745.726985  1196.187693   650.729004   124.655424   278.911104
# min      67.000000     2.000000     0.000000     0.000000     0.000000
# 25%    1039.500000   198.000000   473.000000     0.000000    42.000000
# 50%    1620.000000   511.000000   907.000000     0.000000   106.000000
# 75%    2138.000000  1873.000000  1299.000000     0.000000   384.000000
# max    4139.000000  5155.000000  3478.000000   965.000000  1376.000000
#
#               E_fd        GS_fd         G_fd        Inn_fd        PB_fd  \
# count  1807.000000  1807.000000  1807.000000   1807.000000  1807.000000
# mean    137.673492  1092.532928  1283.230769   9538.370393    13.968456
# std     111.087500   687.844860   618.832745   4669.043102    44.363477
# min       2.000000     0.000000   135.000000    599.000000     0.000000
# 25%      65.500000   612.000000   845.500000   6327.050000     0.000000
# 50%     107.000000  1049.000000  1166.000000   9108.200000     0.000000
# 75%     170.000000  1446.500000  1617.500000  11495.050000     0.000000
# max     853.000000  3660.000000  3786.000000  26416.100000   579.000000
#
#               PO_fd        SB_fd        WP_fd         Ch_fd      Fld%_fd
# count   1807.000000  1807.000000  1807.000000   1807.000000  1807.000000
# mean    3465.816823    72.279469    21.816823   4705.138351     0.967604
# std     2408.449846   179.250479    59.881372   2400.831961     0.025769
# min       80.000000     0.000000     0.000000    201.000000     0.815000
# 25%     1777.000000     0.000000     0.000000   3150.500000     0.961000
# 50%     2865.000000     0.000000     0.000000   4395.000000     0.975000
# 75%     4462.500000     0.000000     0.000000   5882.000000     0.984000
# max    15990.000000  1259.000000   372.000000  17310.000000     0.997000

# %%
features =  ['ten_season_age','debut_decade']+data_set_bat_header 
target = ['HoF']

# %%
features
# Out:
# ['ten_season_age',
#  'debut_decade',
#  '2B_bt',
#  '3B_bt',
#  'AB_bt',
#  'BB_bt',
#  'CS_bt',
#  'G_bt',
#  'HR_bt',
#  'H_bt',
#  'IBB_bt',
#  'PA_bt',
#  'RBI_bt',
#  'R_bt',
#  'SB_bt',
#  'HBP_bt',
#  'SF_bt',
#  'SH_bt',
#  'SO_bt',
#  'BA_bt',
#  'OBP_bt',
#  'OPS_bt',
#  'SLG_bt',
#  'TB_bt',
#  'A_fd',
#  'CG_fd',
#  'CS_fd',
#  'DP_fd',
#  'E_fd',
#  'GS_fd',
#  'G_fd',
#  'Inn_fd',
#  'PB_fd',
#  'PO_fd',
#  'SB_fd',
#  'WP_fd',
#  'Ch_fd',
#  'Fld%_fd']

# %%
X = select_features(inactive_mayors_lg_bat_df, features+target)
X
# Out:
#       ten_season_age  debut_decade  2B_bt  3B_bt   AB_bt  BB_bt  CS_bt  \
# 0                 30          1970  108.0   11.0  2479.0  261.0    9.0
# 1                 33          1990   84.0    6.0  1766.0  180.0    5.0
# 3                 29          1950  321.0   77.0  5940.0  541.0   37.0
# 4                 30          1980   43.0   10.0  1104.0   94.0    5.0
# 5                 33          1980  140.0   39.0  2807.0  386.0   38.0
# ...              ...           ...    ...    ...     ...    ...    ...
# 2333              35          1940  155.0   22.0  3999.0  376.0    7.0
# 2334              29          1900  214.0   80.0  3812.0  192.0   52.0
# 2335              31          1970  193.0   24.0  3999.0  426.0   12.0
# 2337              32          1980  246.0   16.0  4757.0  598.0   44.0
# 2338              33          1880  125.0   48.0  2436.0  212.0    0.0
#
#         G_bt  HR_bt    H_bt  IBB_bt   PA_bt  RBI_bt    R_bt  SB_bt  HBP_bt  \
# 0      812.0   42.0   588.0    44.0  2813.0   290.0   230.0    6.0     7.0
# 1      769.0   18.0   470.0    14.0  2002.0   196.0   203.0   10.0    23.0
# 3     1511.0  342.0  1898.0   124.0  6582.0  1121.0  1077.0  103.0    20.0
# 4      568.0   37.0   260.0    12.0  1244.0   109.0   142.0    7.0    20.0
# 5      995.0   36.0   712.0    24.0  3304.0   304.0   394.0   70.0    38.0
# ...      ...    ...     ...     ...     ...     ...     ...    ...     ...
# 2333  1174.0  230.0  1063.0    39.0  4421.0   750.0   561.0   15.0    24.0
# 2334  1062.0   48.0  1153.0     0.0  4146.0   585.0   535.0  140.0    31.0
# 2335  1138.0  158.0  1150.0    42.0  4475.0   651.0   548.0    6.0     8.0
# 2337  1317.0  159.0  1258.0    33.0  5441.0   707.0   642.0   46.0    25.0
# 2338   676.0   13.0   618.0     0.0  2685.0   344.0   338.0   96.0    35.0
#
#       SF_bt  SH_bt  SO_bt  BA_bt  OBP_bt  OPS_bt  SLG_bt   TB_bt    A_fd  \
# 0      18.0   46.0  383.0  0.237   0.310   0.753   0.443  1005.0   434.0
# 1      16.0   17.0  209.0  0.266   0.339   0.772   0.433   728.0  1016.0
# 3      62.0   19.0  609.0  0.320   0.375   1.206   0.831  4139.0   318.0
# 4      12.0   14.0  220.0  0.236   0.304   0.852   0.548   524.0   867.0
# 5      37.0   36.0  459.0  0.254   0.348   0.791   0.443  1253.0  2174.0
# ...     ...    ...    ...    ...     ...     ...     ...     ...     ...
# 2333   18.0    3.0  728.0  0.266   0.331   1.077   0.746  2359.0   159.0
# 2334    0.0  107.0  336.0  0.302   0.341   0.844   0.503  2013.0  2107.0
# 2335   35.0    7.0  697.0  0.288   0.355   1.016   0.661  2240.0   137.0
# 2337   55.0    6.0  769.0  0.264   0.346   0.948   0.602  2434.0  2104.0
# 2338    0.0    2.0  288.0  0.254   0.322   0.716   0.394  1064.0   954.0
#
#        CG_fd  CS_fd  DP_fd   E_fd   GS_fd    G_fd   Inn_fd  PB_fd   PO_fd  \
# 0      645.0  292.0   57.0   68.0   738.0   800.0   6530.2   60.0  4121.0
# 1      320.0    0.0  183.0   46.0   398.0   580.0   3761.0    0.0   645.0
# 3     2831.0    0.0   63.0  147.0  2957.0  3008.0  26416.1    0.0  6094.0
# 4      183.0    0.0  148.0   54.0   268.0   505.0   2727.0    0.0   483.0
# 5      666.0    0.0  474.0  102.0   740.0   875.0   6671.1    0.0  1590.0
# ...      ...    ...    ...    ...     ...     ...      ...    ...     ...
# 2333  1742.0    0.0   28.0  143.0  1990.0  2014.0  17062.2    0.0  4159.0
# 2334   912.0    0.0  222.0  310.0   972.0  1018.0   8566.0    0.0  1818.0
# 2335  1500.0    0.0   41.0   66.0  1916.0  1990.0  15372.2    0.0  3365.0
# 2337  1195.0   45.0  248.0  188.0  1274.0  1303.0  11237.0   15.0  2020.0
# 2338     0.0  627.0   81.0  251.0     0.0   677.0   5738.0  266.0  2738.0
#
#       SB_fd  WP_fd   Ch_fd  Fld%_fd  HoF
# 0     595.0  213.0  4623.0    0.985    0
# 1       0.0    0.0  1707.0    0.973    0
# 3       0.0    0.0  6559.0    0.978    1
# 4       0.0    0.0  1404.0    0.962    0
# 5       0.0    0.0  3866.0    0.974    0
# ...     ...    ...     ...      ...  ...
# 2333    0.0    0.0  4461.0    0.968    0
# 2334    0.0    0.0  4235.0    0.927    0
# 2335    0.0    0.0  3568.0    0.982    0
# 2337  110.0   38.0  4312.0    0.956    0
# 2338  801.0    0.0  3943.0    0.936    0
#
# [1807 rows x 39 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
hall = X[X['HoF']==1]
no_hall = X[X['HoF']==0]

# %%
from Models.functions.stats_bar import stats_bar_plot

# %%
stats_bar_plot(hall, no_hall, features, 8,5,(22,22))

# %%
def boxplot_generate(hall, no_hall, feature):
    fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 5))
    ax1.set_title("Hall")
    ax2.set_title("NoHall")
    hall.boxplot(feature, ax=ax1)
    no_hall.boxplot(feature, ax=ax2)
    plt.show()

def boxplot_per_feature(hall, no_hall, features):
    for feature in features:
        boxplot_generate(hall, no_hall, feature)

# %%
boxplot_per_feature(hall, no_hall, features)

# %% [markdown]
# Vamos a poner un threshold en 2000 PA

# %%
gt_cond = {
    "PA_bt":1999
}
inactive_mayors_lg_bat_df = filter_dataset(inactive_mayors_lg_bat_df, None, gt_cond, None, None)

# %%
inactive_mayors_lg_bat_df.shape
# Out:
# (1565, 63)

# %%
inactive_mayors_lg_bat_df.describe()
# Out:
#         First year    Last year          HoF  Player type  retirement_age  \
# count  1565.000000  1565.000000  1565.000000       1565.0     1565.000000
# count  1565.000000  1565.000000  1565.000000  1565.000000  1565.000000
# mean    435.829393     0.273069     0.338250     0.847452     0.509203
# std     225.203675     0.025204     0.032474     0.145948     0.127530
# min       0.000000     0.174000     0.195000     0.403000     0.208000
# 25%     266.000000     0.257000     0.318000     0.744000     0.409000
# 50%     399.000000     0.271000     0.337000     0.835000     0.492000
# 75%     563.000000     0.288000     0.358000     0.944000     0.589000
# max    1384.000000     0.377000     0.484000     1.524000     1.047000
#
#              TB_bt         A_fd        CG_fd        CS_fd        DP_fd  \
# count  1565.000000  1565.000000  1565.000000  1565.000000  1565.000000
# mean   1798.792332  1214.185304  1063.424920    44.494569   274.787859
# std     652.672459  1237.335457   633.230131   129.062068   288.150897
# min     506.000000    28.000000     0.000000     0.000000     4.000000
# 25%    1294.000000   222.000000   661.000000     0.000000    48.000000
# 50%    1758.000000   602.000000  1009.000000     0.000000   136.000000
# 75%    2224.000000  2105.000000  1363.000000     0.000000   459.000000
# max    4139.000000  5155.000000  3478.000000   965.000000  1376.000000
#
#               E_fd        GS_fd         G_fd        Inn_fd        PB_fd  \
# count  1565.000000  1565.000000  1565.000000   1565.000000  1565.000000
# mean    151.460064  1201.349521  1396.375080  10446.093291    13.481789
# std     112.216625   671.651818   580.379715   4308.880614    46.261715
# min      13.000000     0.000000   445.000000    983.200000     0.000000
# 25%      78.000000   783.000000   973.000000   7503.000000     0.000000
# 50%     119.000000  1139.000000  1230.000000   9696.100000     0.000000
# 75%     182.000000  1557.000000  1781.000000  11967.100000     0.000000
# max     853.000000  3660.000000  3786.000000  26416.100000   579.000000
#
#               PO_fd        SB_fd        WP_fd         Ch_fd      Fld%_fd
# count   1565.000000  1565.000000  1565.000000   1565.000000  1565.000000
# mean    3761.578275    66.722684    19.591054   5127.223642     0.966942
# std     2425.852349   182.814522    60.451161   2269.860511     0.026240
# min      427.000000     0.000000     0.000000   1043.000000     0.819000
# 25%     1987.000000     0.000000     0.000000   3642.000000     0.960000
# 50%     3172.000000     0.000000     0.000000   4675.000000     0.974000
# 75%     4728.000000     0.000000     0.000000   6119.000000     0.984000
# max    15990.000000  1259.000000   372.000000  17310.000000     0.996000

# %%
y = select_features(inactive_mayors_lg_bat_df, ['HoF'])
X = select_features(inactive_mayors_lg_bat_df, features)

# %%
X.reset_index(inplace=True, drop=True)
y.reset_index(inplace=True, drop=True)

# %%
print(X.index)
y.index
# Out:
# RangeIndex(start=0, stop=1565, step=1)
# RangeIndex(start=0, stop=1565, step=1)

# %%
print(X.shape)
y.shape
# Out:
# (1565, 38)
# (1565, 1)

# %%
y.value_counts()
# Out:
# HoF
# 0      1406
# 1       159
# dtype: int64

# %%
round((159/1565),3)*100
# Out:
# 10.2

# %%
from Models.functions.metrics import show_baseline_score
show_baseline_score(baseline=np.zeros_like(np.ravel(y)), y_val=np.ravel(y))
# Out:
# Accuracy: 0.8984
# AUC: 0.5000

# %%
from Models.functions.models_performance_comparer import performance_comparer

# %%
performance_comparer(X, y)
# Out:
# DecisionTree Gini depth=4
# mACC:0.907
# mAUC:0.775
# <----------------------------------->
#
# DecisionTree Entropy depth=4
# mACC:0.913
# mAUC:0.83
# <----------------------------------->
#
# DecisionTree Gini depth=3
# mACC:0.907
# mAUC:0.775
# <----------------------------------->
#
# DecisionTree Entropy depth=3
# mACC:0.913
# mAUC:0.83
# <----------------------------------->
#
# SVM kernel=poly
# mACC:0.902
# mAUC:0.904
# <----------------------------------->
#
# SVM kernel=rbf
# mACC:0.899
# mAUC:0.917
# <----------------------------------->
#
# Random Forest estimators=10
# mACC:0.923
# mAUC:0.897
# <----------------------------------->
#
# Random Forest estimators=5
# mACC:0.915
# mAUC:0.859
# <----------------------------------->
#
# Naive Bayes
# mACC:0.809
# mAUC:0.873
# <----------------------------------->
#
# 3NN
# mACC:0.901
# mAUC:0.745
# <----------------------------------->
#
# 5NN
# mACC:0.899
# mAUC:0.775
# <----------------------------------->
#
# 10NN
# mACC:0.9
# mAUC:0.815
# <----------------------------------->
#
# LogisticRegression
# mACC:0.935
# mAUC:0.951
# <----------------------------------->

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
from Models.functions.feature_imp import clasifier_ft_importance_experiments, plot_feature_importance

# %%
lr_clf = LogisticRegression(solver='liblinear', max_iter=10000)
plot_feature_importance(clasifier_ft_importance_experiments(lr_clf,X,y,True).sort_values())
# Out:
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/abel/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
rf3_clf = RandomForestClassifier(n_estimators = 3, random_state = 37)
plot_feature_importance(clasifier_ft_importance_experiments(rf3_clf,X,y).sort_values())
# Out:
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)
# /media/abel/LENOVO/AMS/Estudios/4to/Periodismo de datos/Proyecto MLB/DJ-MLB-Hall-Fame/Models/../Models/functions/feature_imp.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clsf_instance.fit(X_train, y_train)

# %%
df = select_features(inactive_mayors_lg_bat_df, features+['HoF'])

df_corr = df.corr()['HoF'].abs().sort_values(ascending=False)
df_corr
# Out:
# HoF               1.000000
# BA_bt             0.468905
# R_bt              0.456734
# TB_bt             0.449784
# H_bt              0.436225
# RBI_bt            0.431936
# OBP_bt            0.413268
# 2B_bt             0.398428
# 3B_bt             0.389291
# PA_bt             0.345443
# AB_bt             0.334894
# OPS_bt            0.314767
# BB_bt             0.294934
# G_bt              0.278177
# SLG_bt            0.254996
# HR_bt             0.246647
# ten_season_age    0.209429
# SB_bt             0.200497
# Ch_fd             0.195009
# IBB_bt            0.169908
# CG_fd             0.165598
# G_fd              0.156885
# Inn_fd            0.154329
# GS_fd             0.140552
# debut_decade      0.140430
# HBP_bt            0.136457
# PO_fd             0.133915
# E_fd              0.130972
# SH_bt             0.102994
# CS_bt             0.096885
# DP_fd             0.089037
# A_fd              0.083314
# SB_fd             0.040955
# SF_bt             0.033705
# CS_fd             0.031779
# WP_fd             0.025898
# Fld%_fd           0.022886
# PB_fd             0.005104
# SO_bt             0.001427
# Name: HoF, dtype: float64

# %%
m_corr = df.corr()

# %%
m_corr
# Out:
#                 ten_season_age  debut_decade     2B_bt     3B_bt     AB_bt  \
# ten_season_age        1.000000      0.002443 -0.123791 -0.094926 -0.150903
# 2B_bt          -0.157668  0.478055  0.124745  0.398428
# 3B_bt          -0.272944  0.292987 -0.292585  0.389291
# AB_bt          -0.219309  0.553709  0.013301  0.334894
# BB_bt          -0.122966  0.370204  0.171579  0.294934
# CS_bt          -0.183528  0.172702  0.272495  0.096885
# G_bt           -0.179153  0.546739  0.223688  0.278177
# HR_bt           0.005750  0.267343  0.322690  0.246647
# H_bt           -0.225522  0.525655  0.007311  0.436225
# IBB_bt          0.153088  0.270037  0.412358  0.169908
# PA_bt          -0.216856  0.558199  0.042926  0.345443
# RBI_bt         -0.116269  0.478208  0.077641  0.431936
# R_bt           -0.284045  0.418824 -0.147432  0.456734
# SB_bt          -0.234216  0.120750 -0.227720  0.200497
# HBP_bt         -0.060580  0.202857  0.005237  0.136457
# SF_bt           0.088109  0.117898  0.420857 -0.033705
# SH_bt          -0.133035  0.230688 -0.029211  0.102994
# SO_bt          -0.021254  0.213315  0.340787 -0.001427
# BA_bt          -0.168661  0.219358 -0.026356  0.468905
# OBP_bt         -0.120945  0.212261  0.139163  0.413268
# OPS_bt          0.018470  0.195880  0.344416  0.314767
# SLG_bt          0.051934  0.170122  0.358724  0.254996
# TB_bt          -0.176156  0.506321  0.126344  0.449784
# A_fd           -0.192842  0.155250 -0.244658  0.083314
# CG_fd          -0.174467  0.269989  0.405239  0.165598
# CS_fd           0.528737 -0.044280  0.092313 -0.031779
# DP_fd          -0.223770  0.656573  0.141155  0.089037
# E_fd           -0.239269  0.137304 -0.791791  0.130972
# GS_fd          -0.171970  0.225281  0.448719  0.140552
# G_fd           -0.257873  0.188678  0.256598  0.156885
# Inn_fd         -0.227345  0.279670  0.245886  0.154329
# PB_fd           0.321087 -0.054555 -0.168962 -0.005104
# PO_fd           0.118922  0.850157  0.445143  0.133915
# SB_fd           0.648310 -0.040875  0.113153 -0.040955
# WP_fd           1.000000  0.010145  0.233892 -0.025898
# Ch_fd           0.010145  1.000000  0.303224  0.195009
# Fld%_fd         0.233892  0.303224  1.000000 -0.022886
# HoF            -0.025898  0.195009 -0.022886  1.000000

# %%
import seaborn as sns
from matplotlib import rcParams

rcParams['figure.figsize'] = 20,20
sns.heatmap(m_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
features
# Out:
# ['ten_season_age',
#  'debut_decade',
#  '2B_bt',
#  '3B_bt',
#  'AB_bt',
#  'BB_bt',
#  'CS_bt',
#  'G_bt',
#  'HR_bt',
#  'H_bt',
#  'IBB_bt',
#  'PA_bt',
#  'RBI_bt',
#  'R_bt',
#  'SB_bt',
#  'HBP_bt',
#  'SF_bt',
#  'SH_bt',
#  'SO_bt',
#  'BA_bt',
#  'OBP_bt',
#  'OPS_bt',
#  'SLG_bt',
#  'TB_bt',
#  'A_fd',
#  'CG_fd',
#  'CS_fd',
#  'DP_fd',
#  'E_fd',
#  'GS_fd',
#  'G_fd',
#  'Inn_fd',
#  'PB_fd',
#  'PO_fd',
#  'SB_fd',
#  'WP_fd',
#  'Ch_fd',
#  'Fld%_fd']

# %%
move = ['AB_bt','CS_bt','HBP_bt','SF_bt','SH_bt', 'SO_bt','OPS_bt','TB_bt','SB_fd','WP_fd','Ch_fd','PB_fd','CG_fd','CS_fd','DP_fd','Inn_fd','A_fd','E_fd','GS_fd','G_fd','PO_fd']
reduced_features = ['ten_season_age','debut_decade','2B_bt','3B_bt','BB_bt','G_bt','HR_bt','H_bt','IBB_bt','PA_bt','RBI_bt','R_bt','SB_bt','BA_bt','OBP_bt','SLG_bt','Fld%_fd']

# %%
X_r = select_features(X, reduced_features)
X_r.reset_index(drop=True, inplace=True)

# %%
X['ten_season_age'].value_counts()
# Out:
# 31    283
# 32    283
# 30    265
# 33    231
# 29    164
# 34    117
# 28     67
# 35     59
# 36     31
# 27     22
# 37     19
# 26      9
# 38      8
# 39      4
# 40      1
# 43      1
# 42      1
# Name: ten_season_age, dtype: int64

# %%
df = select_features(inactive_mayors_lg_bat_df, reduced_features+['HoF'])

df_corr = df.corr()['HoF'].abs().sort_values(ascending=False)
df_corr
# Out:
# HoF               1.000000
# BA_bt             0.468905
# R_bt              0.456734
# H_bt              0.436225
# RBI_bt            0.431936
# OBP_bt            0.413268
# 2B_bt             0.398428
# 3B_bt             0.389291
# PA_bt             0.345443
# BB_bt             0.294934
# G_bt              0.278177
# SLG_bt            0.254996
# HR_bt             0.246647
# ten_season_age    0.209429
# SB_bt             0.200497
# IBB_bt            0.169908
# debut_decade      0.140430
# Fld%_fd           0.022886
# Name: HoF, dtype: float64

# %%
m_corr = df.corr()

# %%
rcParams['figure.figsize'] = 14,14
sns.heatmap(m_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Probamos nuevamente los modelos

# %%
performance_comparer(X_r, y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_t = sc.fit_transform(X_r)

# %%
performance_comparer(X_t, y)

# %%
#print('DecisionTree Gini depth=4')
dtg4_clf = DecisionTreeClassifier(criterion='gini', max_depth=4)

##print('DecisionTree Entropy depth=4')
dte4_clf = DecisionTreeClassifier(criterion='entropy', max_depth=4)

#print('DecisionTree Gini depth=3')
dtg3_clf = DecisionTreeClassifier(criterion='gini', max_depth=3)  

#print('DecisionTree Entropy depth=3')
dte3_clf = DecisionTreeClassifier(criterion='entropy', max_depth=3))   

#print('SVM kernel=poly')
svmp_clf = SVC(probability=True, kernel='poly')

#print('SVM kernel=rbf')
svmr_clf = SVC(probability=True, kernel='rbf')

#print('LogisticRegression')
lr_clf = LogisticRegression(max_iter=10000, solver="liblinear")
models  = [dte4_clf, dte4_clf, dte3_clf, dtg3_clf, svmr_clf, svmp_clf, lr_clf]
models_label = ['dtg4','dte4', 'dte3', 'dtg3','svm_r','svm_p','lr']

# %%
from Models.functions.models_performance_comparer import performance_comparer_plus

# %%
performance_comparer_plus(X_t, y, models, models_label)

# %% [markdown]
# Vamos a reducir dimensiones

# %%
from sklearn.decomposition import PCA

# %%
pca3 = PCA(n_components=3)
X_pca3_r = pca3.fit_transform(X_t)
print('explained variance ratio (for components): %s'
                        # %str(pca3.explained_variance_ratio_))

# %%
from Models.functions.data_set_plot import plot_2d_data, plot_3d_data
rcParams['figure.figsize'] = 8,6

# %%
plot_3d_data(X_pca3_r,y.to_numpy())
