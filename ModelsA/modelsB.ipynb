# %%
#Execute this cell if have problem with relative import

import sys; sys.path.insert(0, '..')

# %%
from pprint import pprint

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
bat_df = pd.read_csv("../Data/Corpus_csv/pitchers_all_career.csv")

# %%
bat_df.head()
# Out:
#                 Id         Name  Active  First year  Last year  \
# 0  Jay_Aldrich_192  Jay Aldrich   False        1987       1990
# 1   A.J._Achter_52  A.J. Achter   False        2014       2016
# 2   A.J._Alexy_214   A.J. Alexy    True        2021       2021
# 3  Aaron_Ashby_601  Aaron Ashby    True        2021       2022
# 4  Abe_Alvarez_329  Abe Alvarez   False        2004       2006
#
#                                                  Url Country Bat hand  \
# 0  https://www.baseball-reference.com//players/a/...      us    Right
# 1  https://www.baseball-reference.com//players/a/...      us    Right
# 2  https://www.baseball-reference.com//players/a/...      us    Right
# 3  https://www.baseball-reference.com//players/a/...      us    Right
# 4  https://www.baseball-reference.com//players/a/...      us     Left
#
#   Throw hand            Full Name  HoF HoF type HoF year HoF comittee  \
# 0      Right   Jay Robert Aldrich    0        -        -            -
# 1      Right   Adam Joseph Achter    0        -        -            -
# 2      Right      Adam John Alexy    0        -        -            -
# 3       Left  Aaron Phillip Ashby    0        -        -            -
# 4       Left      Abraham Alvarez    0        -        -            -
#
#    Player type retirement_age  total_seasons    career_teams career_leagues  \
# 0            1             29              3  ['MIL', 'BAL']   ['AL', 'NL']
# 1            1             27              3  ['MIN', 'LAA']         ['AL']
# 2            1             23              1         ['TEX']         ['AL']
# 3            1             24              2         ['MIL']         ['NL']
# 4            1             23              3         ['BOS']         ['AL']
#
#   first_position second_position  play_in_mayors  play_in_negro_league  \
# 0              P               -               1                     0
# 1              P               -               1                     0
# 2              P               -               1                     0
# 3              P               -               1                     0
# 4              P               -               1                     0
#
#    two_way_player  W_pt  L_pt  W-L%_pt  ERA_pt  G_pt  GS_pt  GF_pt  CG_pt  \
# 0               0   NaN   NaN      NaN     NaN   NaN    NaN    NaN    NaN
# 1               0   NaN   NaN      NaN     NaN   NaN    NaN    NaN    NaN
# 2               0   NaN   NaN      NaN     NaN   NaN    NaN    NaN    NaN
# 3               0   NaN   NaN      NaN     NaN   NaN    NaN    NaN    NaN
# 4               0   NaN   NaN      NaN     NaN   NaN    NaN    NaN    NaN
#
#    SHO_pt  SV_pt  IP_pt  H_pt  R_pt  ER_pt  HR_pt  BB_pt  IBB_pt  SO_pt  \
# 0     NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
# 1     NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
# 2     NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
# 3     NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
# 4     NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
#
#    HBP_pt  BK_pt  WP_pt  BF_pt  ERA+_pt  FIP_pt  WHIP_pt  H9_pt  HR9_pt  \
# 0     NaN    NaN    NaN    NaN      NaN     NaN      NaN    NaN     NaN
# 1     NaN    NaN    NaN    NaN      NaN     NaN      NaN    NaN     NaN
# 2     NaN    NaN    NaN    NaN      NaN     NaN      NaN    NaN     NaN
# 3     NaN    NaN    NaN    NaN      NaN     NaN      NaN    NaN     NaN
# 4     NaN    NaN    NaN    NaN      NaN     NaN      NaN    NaN     NaN
#
#    BB9_pt  SO9_pt  SO/W_pt  RAA_pt  WAA_pt  WAR_pt  RAR_pt
# 0     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN      NaN     NaN     NaN     NaN     NaN

# %%
bat_df.shape
# Out:
# (9707, 58)

# %%
from Preprocessing.data_keys import headers_bio, headers_bat

# %%
from Preprocessing.data_frame_procces import filter_dataset, select_features
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/modelsB.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/modelsB.ipynb#ch0000006?line=0'>1</a> from Preprocessing.data_frame_procces import filter_dataset, select_features
#
# File ~/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/../Preprocessing/data_frame_procces.py:3, in <module>
#       <a href='file:///home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/../Preprocessing/data_frame_procces.py?line=0'>1</a> from typing import Dict, List
#       <a href='file:///home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/../Preprocessing/data_frame_procces.py?line=1'>2</a> import pandas as pd
# ----> <a href='file:///home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/../Preprocessing/data_frame_procces.py?line=2'>3</a> from sklearn.preprocessing import LabelEncoder
#       <a href='file:///home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/../Preprocessing/data_frame_procces.py?line=5'>6</a> def select_features(df:pd.DataFrame, features:List)->pd.DataFrame:
#       <a href='file:///home/Belzico/Documents/GitHub/DJ-MLB-Hall-Fame/ModelsA/../Preprocessing/data_frame_procces.py?line=6'>7</a>     return df[features]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
gt_conditions = {
    "total_seasons":3,
    'G_bt':100
}
eq_conditions = {
    "HoF type":['-','Player']
}
filter_df = filter_dataset(bat_df, eq_conditions,gt_conditions, None, None)
